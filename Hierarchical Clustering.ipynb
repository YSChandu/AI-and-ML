# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"D:\Udemy\Ml_AtoZ\Machine Learning-A-Z-Codes-Datasets\Machine Learning A-Z (Codes and Datasets)\Part 4 - Clustering\Section 24 - K-Means Clustering\Python\Mall_Customers.csv")

# %%
x = dataset.iloc[:,[3,4]].values

# %%
# using dendogram to compute the optimal number of the clusters
import scipy.cluster.hierarchy as s
dendrogram = s.dendrogram(s.linkage(x , method = 'ward'))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5 , affinity = 'euclidean',linkage='ward')
hc =hc.fit_predict(x)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# visualization
plt.scatter(x[hc==0,0],x[hc==0,1],s=50,c ='red',label='cluster 1')
plt.scatter(x[hc==1,0],x[hc==1,1],s=50,c ='blue',label='cluster 2')
plt.scatter(x[hc==2,0],x[hc==2,1],s=50,c ='green',label='cluster 3')
plt.scatter(x[hc==3,0],x[hc==3,1],s=50,c ='cyan',label='cluster 4')
plt.scatter(x[hc==4,0],x[hc==4,1],s=50,c ='magenta',label='cluster 5')
plt.legend()
plt.show()
